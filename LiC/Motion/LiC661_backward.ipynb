# %%
import matplotlib.pyplot as plt
import Motion_Form as mf

# %%
S1 = [
    [25, -0.1705437181594107],
    [28, -0.21028007840648116],
    [30, -0.2078624479467962],
    [35, -0.27586866348468564],
    [40, -0.3332723014413087],
    [45, -0.30701792122565275],
]
R10 = [
    [30, 1.2910431802632993],
    [40, ],
    [50, ],
]
R33 = [
    [30, ],
    [40, ],
    [50, ],
]
R50 = [
    [30, ],
    [40, ],
    [50, ],
]

# %%
mf.pre_plot()

plt.plot(*zip(*S1), label='Graphene', color='red', ls=':', marker='^')
# plt.plot(*zip(*R10), label='a10', color='green', ls=':', marker='s')
# plt.plot(*zip(*R33), label='a33', color='blue', ls=':', marker='o')
# plt.plot(*zip(*R50), label='a50', color='orange', ls=':', marker='x')

mf.post_plot("Backward Motion", yscale=-1)
