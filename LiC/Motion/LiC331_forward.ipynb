# %%
import matplotlib.pyplot as plt
import Motion_Form as mf

# %%
S0 = [
    [15, 0.13700371591624733],
    [20, 0.20624544534156658],
    [25, 0.26493695803403633],
    [28, 0.35488782099090266],
    [30, 2.35305562431043260],
    [35, 4.6143898389326700],
    [40, 6.4626418824340700],
]
S1 = [
    [25, 0.27174621673181887],
    [28, 0.3548506808099295],
    [30, 1.265219772456655],
    [35, 1.3249732734590318],
    [40, 1.1818854128330196],
    [45, 1.252985861125614],
    [50, 2.166574493851839],
]
S2AA = [
    [10, 0.10263433968387706],
    [15, 0.15660125596520902],
    [20, 0.21549474221950407],
    [25, 0.2852775783967787],
    [30, 0.38216757304254917],
    [35, 3.229179917009127],
    [40, 4.3651232980139385],
    [45, 4.270737919047873],
]
S2AB = [
    [10, 0.45642132799764484],
    [15, 0.53811052606816580],
    [20, 0.74489444871457800],
    [25, 1.19478320397798730],
]

# %%
mf.pre_plot()

# plt.plot(*zip(*S0), label='Graphene (Fixed)', color='blue', ls=':', marker='o')
plt.plot(*zip(*S1), label='Graphene', color='red', ls=':', marker='^')
plt.plot(*zip(*S2AA), label='Bilayer Graphene (AA)', color='green', ls=':', marker='s')


mf.post_plot("Forward Motion")
